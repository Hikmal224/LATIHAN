# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns

# %%
df = pd.read_csv("/data_balita.csv")

# %%
df
# Out:
#         Umur (bulan) Jenis Kelamin  Tinggi Badan (cm)       Status Gizi
# 0                  0     laki-laki          44.591973           stunted
# 1                  0     laki-laki          56.705203            tinggi
# 2                  0     laki-laki          46.863358            normal
# 3                  0     laki-laki          47.508026            normal
# 4                  0     laki-laki          42.743494  severely stunted
# ...              ...           ...                ...               ...
# 120994            60     perempuan         100.600000            normal
# 120995            60     perempuan          98.300000           stunted
# 120996            60     perempuan         121.300000            normal
# 120997            60     perempuan         112.200000            normal
# 120998            60     perempuan         109.800000            normal
#
# [120999 rows x 4 columns]

# %%
df.columns = ['Age', 'Gender','Height','Status']

# %%
df
# Out:
#         Age     Gender      Height            Status
# 0         0  laki-laki   44.591973           stunted
# 1         0  laki-laki   56.705203            tinggi
# 2         0  laki-laki   46.863358            normal
# 3         0  laki-laki   47.508026            normal
# 4         0  laki-laki   42.743494  severely stunted
# ...     ...        ...         ...               ...
# 120994   60  perempuan  100.600000            normal
# 120995   60  perempuan   98.300000           stunted
# 120996   60  perempuan  121.300000            normal
# 120997   60  perempuan  112.200000            normal
# 120998   60  perempuan  109.800000            normal
#
# [120999 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120999 entries, 0 to 120998
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Age     120999 non-null  int64
#  1   Gender  120999 non-null  object
#  2   Height  120999 non-null  float64
#  3   Status  120999 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.7+ MB

# %% [markdown]
# ** 1. Data Understanding**

# %%
print("data shape :", df.shape)
# Out:
# data shape : (120999, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120999 entries, 0 to 120998
# Data columns (total 4 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Age     120999 non-null  int64
#  1   Gender  120999 non-null  object
#  2   Height  120999 non-null  float64
#  3   Status  120999 non-null  object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                  Age         Height
# count  120999.000000  120999.000000
# mean       30.173803      88.655434
# std        17.575119      17.300997
# min         0.000000      40.010437
# 25%        15.000000      77.000000
# 50%        30.000000      89.800000
# 75%        45.000000     101.200000
# max        60.000000     128.000000

# %%
df.Status.value_counts()
# Out:
# Status
# normal              67755
# severely stunted    19869
# tinggi              19560
# stunted             13815
# Name: count, dtype: int64

# %%
df.Gender.value_counts()
# Out:
# Gender
# perempuan    61002
# laki-laki    59997
# Name: count, dtype: int64

# %%
sns.histplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# **2. Cleaning Data**

# %%
df.isnull().sum()
# Out:
# Age       0
# Gender    0
# Height    0
# Status    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 81574

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **3. Exploratory Data Analysis (EDA)**

# %%
sns.set_theme(style='ticks')
sns.countplot(x='Status', data=df, palette='flare')
plt.ylabel('Total/Jumlah')
plt.xlabel('Gizi')
plt.show()
# Out:
# <ipython-input-273-78e209ce3415>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Status', data=df, palette='flare')

# %%
sns.set_theme(style='darkgrid')
sns.countplot(x='Gender', data=df, palette='rocket')
plt.ylabel('Jumlah')
plt.xlabel('Jenis Kelamin')
plt.show()
# Out:
# <ipython-input-276-cca3eb6c938b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette='rocket')

# %% [markdown]
# **3. Data Preparation**

# %%
df.head()
# Out:
#    Age     Gender     Height            Status
# 0    0  laki-laki  44.591973           stunted
# 1    0  laki-laki  56.705203            tinggi
# 2    0  laki-laki  46.863358            normal
# 3    0  laki-laki  47.508026            normal
# 4    0  laki-laki  42.743494  severely stunted

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['Gender'] = label_encoder.fit_transform(df['Gender'])
df['Status'] = label_encoder.fit_transform(df['Status'])
# Out:
# <ipython-input-279-8a062a75b51a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = label_encoder.fit_transform(df['Gender'])
# <ipython-input-279-8a062a75b51a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Status'] = label_encoder.fit_transform(df['Status'])

# %%
df.head()
# Out:
#    Age  Gender     Height  Status
# 0    0       0  44.591973       2
# 1    0       0  56.705203       3
# 2    0       0  46.863358       0
# 3    0       0  47.508026       0
# 4    0       0  42.743494       1

# %%
x = df.drop(columns=['Status'])
y = df['Status']

print("x :", x.shape)
print("y :", y.shape)
# Out:
# x : (39425, 3)
# y : (39425,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
print("x_train :", x_train.shape)
print("y_train :", y_train.shape)
print("x_test :", x_test.shape)
print("y_test :", y_test.shape)
# Out:
# x_train : (31540, 3)
# y_train : (31540,)
# x_test : (7885, 3)
# y_test : (7885,)

# %% [markdown]
# **4. Modeling**

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)
KNN_acc = accuracy_score(y_pred, y_test)

print(classification_report(y_pred, y_test))
print("Akurasi KNN : {:.2f}%".format(KNN_acc*100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      4338
#            1       0.99      0.99      0.99      1337
#            2       0.97      0.98      0.98       833
#            3       0.99      0.99      0.99      1377
#
#     accuracy                           0.99      7885
#    macro avg       0.99      0.99      0.99      7885
# weighted avg       0.99      0.99      0.99      7885
#
# Akurasi KNN : 99.14%

# %%
testing = {'Age': [0],
        'Gender': [0],
        'Height': [44.59197]}

testing = pd.DataFrame(testing)
testing
# Out:
#    Age  Gender    Height
# 0    0       0  44.59197

# %%
pred_coba = knn.predict(testing)
print("Hasil Prediksi")
print(pred_coba)
# Out:
# Hasil Prediksi
# [2]
